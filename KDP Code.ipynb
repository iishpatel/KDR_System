# %%
## IE 3311 Final Project
## Ishan Patel

# %%
# import necessary libraries
import json
import networkx as nx
import gurobipy as gp
from gurobipy import GRB

# %%
# Load KDP data from the location of the JSON file
with open('C:/Users/ishan/Desktop/OR Project/KDPlist.json', 'r') as file:
    data = json.load(file)

# %%
# Create a directed graph that represents donor-recipient relationships
G = nx.DiGraph()

# %%
# Add nodes with donor-recipient information
for idx, element in enumerate(data):
    G.add_node(idx, **element)

# %%
# creating a dictionary of compatibility rules based on blood types
DRC = {
    'O': ['O', 'A', 'B', 'AB'],
    'A': ['A', 'AB'],
    'B': ['B', 'AB'],
    'AB': ['AB']
}

# %%
# Add edges between nodes if both donor and recipient are compatible
for donor_node in G.nodes:
    donors = G.nodes[donor_node]['Donor']
    for donor in donors:
        for recipient_node in G.nodes:
            if donor_node == recipient_node:
                continue
            recipient = G.nodes[recipient_node]['Recipient']
            if recipient in DRC[donor]:
                G.add_edge(donor_node, recipient_node)

# %%
# Identify cycles of length 2
cycle_2 = []

for (i, j) in G.edges:# indicates that donor i is compatible with recipient j and could potentially donate a kidney.
    if (j, i) in G.edges:  # indicates that donor j is compatible with recipient i
        cycle_2.append((i, j))

# %%
# Identify cycles of length 3
potential_cycle_3 = []  # potential 3-way cycles
H = G.to_undirected()  

# identify potential 3-way cycles
for (u, v) in H.edges:
    for k in nx.common_neighbors(H, u, v): 
        potential_cycle_3.append((u, v, k)) 
# u is the first donor-recipient pair in the cycle
# v is the second donor-recipient pair in the cycle
# k is the third donor-recipient pair in the cycle

cycle_3 = []  # Final list of valid 3-way cycles
for (u, v, k) in potential_cycle_3:
    if (u, v) in G.edges and (v, k) in G.edges and (k, u) in G.edges:
        cycle_3.append((u, v, k))

# %%
# Optimization using Gurobi
model = gp.Model("KPD_Optimization")

# %%
# Define decision variables for cycles

# Binary variable: 1 if cycle is selected, 0 otherwise 
x_2 = {cycle: model.addVar(vtype=GRB.BINARY, name=f"x_2_{cycle}") for cycle in cycle_2} 

# Binary variable: 1 if cycle is selected, 0 otherwise  
x_3 = {cycle: model.addVar(vtype=GRB.BINARY, name=f"x_3_{cycle}") for cycle in cycle_3}

# Define compatibility scores
# Compatibility scores represent the likelihood of a successful transplant between donor `u` and recipient `v`
compatibility_scores = {(u, v): G[u][v].get('weight', 1) for u, v in G.edges}

# Objective function: Maximize compatibility scores
model.setObjective(
    gp.quicksum(x_2[cycle] for cycle in cycle_2) +
    gp.quicksum(x_3[cycle] for cycle in cycle_3),
    GRB.MAXIMIZE
)

# %%
# Constraint: Ensure no node is part of multiple cycles
# Each donor-recipient pair (node) can be in one cycle at most
# A node can be in one 2-way cycle or one 3-way cycle, but not both
for node in G.nodes:
    model.addConstr(
        gp.quicksum(x_2[cycle] for cycle in cycle_2 if node in cycle) + # Sum for 2-way cycles involving the node
       # Sum for 3-way cycles involving the node
        gp.quicksum(x_3[cycle] for cycle in cycle_3 if node in cycle) <= 1, # The sum is set to 1 so that way no node is selected in multiple cycles.
        name=f"Node_{node}_Participation"
    )

# After adding all constraints and variables
model.update()

# %%
# Solve the model
model.optimize()
# Out:
# Gurobi Optimizer version 11.0.3 build v11.0.3rc0 (win64 - Windows 11.0 (22631.2))
#
# CPU model: AMD Ryzen 7 2700X Eight-Core Processor, instruction set [SSE2|AVX|AVX2]
# Thread count: 8 physical cores, 16 logical processors, using up to 16 threads
#
# Academic license 2553316 - for non-commercial use only - registered to is___@ttu.edu
# Optimize a model with 725 rows, 77700 columns and 155400 nonzeros
# Model fingerprint: 0xdc5218a7
# Variable types: 0 continuous, 77700 integer (77700 binary)
# Coefficient statistics:
#   Matrix range     [1e+00, 1e+00]
#   Objective range  [1e+00, 1e+00]
#   Bounds range     [1e+00, 1e+00]
#   RHS range        [1e+00, 1e+00]
# Found heuristic solution: objective 185.0000000
# Presolve removed 330 rows and 38850 columns
# Presolve time: 0.16s
# Presolved: 395 rows, 38850 columns, 77700 nonzeros
# Found heuristic solution: objective 185.0000000
# Variable types: 0 continuous, 38850 integer (38850 binary)
#
# Starting sifting (using dual simplex for sub-problems)...
#
#     Iter     Pivots    Primal Obj      Dual Obj        Time
#        0          0     infinity     -3.9400000e+02      0s
#        1        504  -1.8000000e+01  -2.0500000e+02      0s
#        2       1302  -1.8494831e+02  -1.8494904e+02      0s
#
# Sifting complete
#
#
# Root relaxation: cutoff, 1779 iterations, 0.04 seconds (0.04 work units)
#
#     Nodes    |    Current Node    |     Objective Bounds      |     Work
#  Expl Unexpl |  Obj  Depth IntInf | Incumbent    BestBd   Gap | It/Node Time
#
#      0     0     cutoff    0       185.00000  185.00000  0.00%     -    0s
#
# Explored 1 nodes (1779 simplex iterations) in 0.30 seconds (0.33 work units)
# Thread count was 16 (of 16 available processors)
#
# Solution count 2: 185 185
#
# Optimal solution found (tolerance 1.00e-04)
# Best objective 1.850000000000e+02, best bound 1.850000000000e+02, gap 0.0000%

# %%
# Output solution
if model.status == GRB.OPTIMAL:
    print("You Did It! We Got A Pair!") # Print confirmation that a feasible solution was found
    
    # Print selected 2-way cycles
    print("\nSelected 2-Way Cycles:")
    for cycle in x_2:
        if x_2[cycle].x > 0.5:
            print(f"Cycle: {cycle[0]} & {cycle[1]} (Donor {cycle[0]} matches Recipient {cycle[1]})") 
    
    # Print selected 3-way cycles
    print("\nSelected 3-Way Cycles:")
    for cycle in x_3:
        if x_3[cycle].x > 0.5:
            print(f"Cycle: {cycle[0]} → {cycle[1]} → {cycle[2]} → {cycle[0]} "
                  f"(Donor {cycle[0]} matches Recipient {cycle[1]}, "
                  f"Donor {cycle[1]} matches Recipient {cycle[2]}, "
                  f"Donor {cycle[2]} matches Recipient {cycle[0]})")
else:
    print("No optimal solution found.")
# Out:
# You Did It! We Got A Pair!
#
# Selected 2-Way Cycles:
# Cycle: 0 & 9 (Donor 0 matches Recipient 9)
# Cycle: 1 & 23 (Donor 1 matches Recipient 23)
# Cycle: 4 & 5 (Donor 4 matches Recipient 5)
# Cycle: 6 & 25 (Donor 6 matches Recipient 25)
# Cycle: 12 & 13 (Donor 12 matches Recipient 13)
# Cycle: 15 & 40 (Donor 15 matches Recipient 40)
# Cycle: 16 & 47 (Donor 16 matches Recipient 47)
# Cycle: 19 & 34 (Donor 19 matches Recipient 34)
# Cycle: 24 & 53 (Donor 24 matches Recipient 53)
# Cycle: 26 & 28 (Donor 26 matches Recipient 28)
# Cycle: 27 & 41 (Donor 27 matches Recipient 41)
# Cycle: 31 & 65 (Donor 31 matches Recipient 65)
# Cycle: 33 & 44 (Donor 33 matches Recipient 44)
# Cycle: 35 & 50 (Donor 35 matches Recipient 50)
# Cycle: 36 & 60 (Donor 36 matches Recipient 60)
# Cycle: 39 & 80 (Donor 39 matches Recipient 80)
# Cycle: 48 & 96 (Donor 48 matches Recipient 96)
# Cycle: 52 & 71 (Donor 52 matches Recipient 71)
# Cycle: 54 & 64 (Donor 54 matches Recipient 64)
# Cycle: 57 & 73 (Donor 57 matches Recipient 73)
# Cycle: 61 & 75 (Donor 61 matches Recipient 75)
# Cycle: 62 & 67 (Donor 62 matches Recipient 67)
# Cycle: 63 & 82 (Donor 63 matches Recipient 82)
# Cycle: 77 & 88 (Donor 77 matches Recipient 88)
# Cycle: 83 & 94 (Donor 83 matches Recipient 94)
# Cycle: 84 & 92 (Donor 84 matches Recipient 92)
# Cycle: 86 & 111 (Donor 86 matches Recipient 111)
# Cycle: 91 & 97 (Donor 91 matches Recipient 97)
# Cycle: 95 & 103 (Donor 95 matches Recipient 103)
# Cycle: 100 & 102 (Donor 100 matches Recipient 102)
# Cycle: 110 & 123 (Donor 110 matches Recipient 123)
# Cycle: 113 & 117 (Donor 113 matches Recipient 117)
# Cycle: 114 & 160 (Donor 114 matches Recipient 160)
# Cycle: 116 & 120 (Donor 116 matches Recipient 120)
# Cycle: 119 & 124 (Donor 119 matches Recipient 124)
# Cycle: 122 & 134 (Donor 122 matches Recipient 134)
# Cycle: 128 & 130 (Donor 128 matches Recipient 130)
# Cycle: 132 & 135 (Donor 132 matches Recipient 135)
# Cycle: 133 & 147 (Donor 133 matches Recipient 147)
# Cycle: 138 & 152 (Donor 138 matches Recipient 152)
# Cycle: 139 & 153 (Donor 139 matches Recipient 153)
# Cycle: 142 & 157 (Donor 142 matches Recipient 157)
# Cycle: 144 & 146 (Donor 144 matches Recipient 146)
# Cycle: 148 & 161 (Donor 148 matches Recipient 161)
# Cycle: 149 & 175 (Donor 149 matches Recipient 175)
# Cycle: 154 & 180 (Donor 154 matches Recipient 180)
# Cycle: 162 & 176 (Donor 162 matches Recipient 176)
# Cycle: 168 & 177 (Donor 168 matches Recipient 177)
# Cycle: 169 & 172 (Donor 169 matches Recipient 172)
# Cycle: 171 & 191 (Donor 171 matches Recipient 191)
# Cycle: 173 & 188 (Donor 173 matches Recipient 188)
# Cycle: 184 & 197 (Donor 184 matches Recipient 197)
# Cycle: 186 & 229 (Donor 186 matches Recipient 229)
# Cycle: 187 & 198 (Donor 187 matches Recipient 198)
# Cycle: 189 & 206 (Donor 189 matches Recipient 206)
# Cycle: 193 & 226 (Donor 193 matches Recipient 226)
# Cycle: 195 & 215 (Donor 195 matches Recipient 215)
# Cycle: 201 & 246 (Donor 201 matches Recipient 246)
# Cycle: 209 & 224 (Donor 209 matches Recipient 224)
# Cycle: 211 & 223 (Donor 211 matches Recipient 223)
# Cycle: 213 & 225 (Donor 213 matches Recipient 225)
# Cycle: 222 & 233 (Donor 222 matches Recipient 233)
# Cycle: 228 & 258 (Donor 228 matches Recipient 258)
# Cycle: 230 & 234 (Donor 230 matches Recipient 234)
# Cycle: 232 & 250 (Donor 232 matches Recipient 250)
# Cycle: 235 & 242 (Donor 235 matches Recipient 242)
# Cycle: 240 & 257 (Donor 240 matches Recipient 257)
# Cycle: 241 & 251 (Donor 241 matches Recipient 251)
# Cycle: 243 & 245 (Donor 243 matches Recipient 245)
# Cycle: 244 & 249 (Donor 244 matches Recipient 249)
# Cycle: 252 & 255 (Donor 252 matches Recipient 255)
# Cycle: 260 & 302 (Donor 260 matches Recipient 302)
# Cycle: 261 & 269 (Donor 261 matches Recipient 269)
# Cycle: 267 & 272 (Donor 267 matches Recipient 272)
# Cycle: 270 & 277 (Donor 270 matches Recipient 277)
# Cycle: 271 & 280 (Donor 271 matches Recipient 280)
# Cycle: 278 & 293 (Donor 278 matches Recipient 293)
# Cycle: 281 & 282 (Donor 281 matches Recipient 282)
# Cycle: 285 & 306 (Donor 285 matches Recipient 306)
# Cycle: 287 & 295 (Donor 287 matches Recipient 295)
# Cycle: 290 & 297 (Donor 290 matches Recipient 297)
# Cycle: 299 & 311 (Donor 299 matches Recipient 311)
# Cycle: 300 & 316 (Donor 300 matches Recipient 316)
# Cycle: 303 & 320 (Donor 303 matches Recipient 320)
# Cycle: 308 & 319 (Donor 308 matches Recipient 319)
# Cycle: 317 & 332 (Donor 317 matches Recipient 332)
# Cycle: 327 & 334 (Donor 327 matches Recipient 334)
# Cycle: 328 & 395 (Donor 328 matches Recipient 395)
# Cycle: 330 & 354 (Donor 330 matches Recipient 354)
# Cycle: 331 & 350 (Donor 331 matches Recipient 350)
# Cycle: 333 & 370 (Donor 333 matches Recipient 370)
# Cycle: 338 & 371 (Donor 338 matches Recipient 371)
# Cycle: 339 & 374 (Donor 339 matches Recipient 374)
# Cycle: 342 & 375 (Donor 342 matches Recipient 375)
# Cycle: 343 & 382 (Donor 343 matches Recipient 382)
# Cycle: 344 & 368 (Donor 344 matches Recipient 368)
# Cycle: 345 & 389 (Donor 345 matches Recipient 389)
# Cycle: 346 & 385 (Donor 346 matches Recipient 385)
# Cycle: 347 & 421 (Donor 347 matches Recipient 421)
# Cycle: 357 & 406 (Donor 357 matches Recipient 406)
# Cycle: 358 & 407 (Donor 358 matches Recipient 407)
# Cycle: 359 & 402 (Donor 359 matches Recipient 402)
# Cycle: 361 & 423 (Donor 361 matches Recipient 423)
# Cycle: 363 & 432 (Donor 363 matches Recipient 432)
# Cycle: 364 & 486 (Donor 364 matches Recipient 486)
# Cycle: 366 & 436 (Donor 366 matches Recipient 436)
# Cycle: 372 & 431 (Donor 372 matches Recipient 431)
# Cycle: 373 & 441 (Donor 373 matches Recipient 441)
# Cycle: 376 & 438 (Donor 376 matches Recipient 438)
# Cycle: 377 & 454 (Donor 377 matches Recipient 454)
# Cycle: 387 & 457 (Donor 387 matches Recipient 457)
# Cycle: 391 & 458 (Donor 391 matches Recipient 458)
# Cycle: 393 & 465 (Donor 393 matches Recipient 465)
# Cycle: 397 & 470 (Donor 397 matches Recipient 470)
# Cycle: 400 & 473 (Donor 400 matches Recipient 473)
# Cycle: 408 & 475 (Donor 408 matches Recipient 475)
# Cycle: 413 & 480 (Donor 413 matches Recipient 480)
# Cycle: 415 & 481 (Donor 415 matches Recipient 481)
# Cycle: 417 & 484 (Donor 417 matches Recipient 484)
# Cycle: 418 & 449 (Donor 418 matches Recipient 449)
# Cycle: 422 & 502 (Donor 422 matches Recipient 502)
# Cycle: 427 & 494 (Donor 427 matches Recipient 494)
# Cycle: 428 & 493 (Donor 428 matches Recipient 493)
# Cycle: 434 & 549 (Donor 434 matches Recipient 549)
# Cycle: 435 & 507 (Donor 435 matches Recipient 507)
# Cycle: 442 & 528 (Donor 442 matches Recipient 528)
# Cycle: 446 & 522 (Donor 446 matches Recipient 522)
# Cycle: 448 & 523 (Donor 448 matches Recipient 523)
# Cycle: 450 & 524 (Donor 450 matches Recipient 524)
# Cycle: 453 & 526 (Donor 453 matches Recipient 526)
# Cycle: 456 & 506 (Donor 456 matches Recipient 506)
# Cycle: 460 & 556 (Donor 460 matches Recipient 556)
# Cycle: 464 & 535 (Donor 464 matches Recipient 535)
# Cycle: 466 & 539 (Donor 466 matches Recipient 539)
# Cycle: 467 & 542 (Donor 467 matches Recipient 542)
# Cycle: 468 & 544 (Donor 468 matches Recipient 544)
# Cycle: 471 & 547 (Donor 471 matches Recipient 547)
# Cycle: 472 & 571 (Donor 472 matches Recipient 571)
# Cycle: 474 & 566 (Donor 474 matches Recipient 566)
# Cycle: 482 & 513 (Donor 482 matches Recipient 513)
# Cycle: 483 & 558 (Donor 483 matches Recipient 558)
# Cycle: 487 & 552 (Donor 487 matches Recipient 552)
# Cycle: 489 & 529 (Donor 489 matches Recipient 529)
# Cycle: 491 & 572 (Donor 491 matches Recipient 572)
# Cycle: 496 & 580 (Donor 496 matches Recipient 580)
# Cycle: 498 & 587 (Donor 498 matches Recipient 587)
# Cycle: 500 & 630 (Donor 500 matches Recipient 630)
# Cycle: 508 & 605 (Donor 508 matches Recipient 605)
# Cycle: 510 & 588 (Donor 510 matches Recipient 588)
# Cycle: 514 & 650 (Donor 514 matches Recipient 650)
# Cycle: 515 & 617 (Donor 515 matches Recipient 617)
# Cycle: 527 & 620 (Donor 527 matches Recipient 620)
# Cycle: 530 & 606 (Donor 530 matches Recipient 606)
# Cycle: 536 & 633 (Donor 536 matches Recipient 633)
# Cycle: 537 & 667 (Donor 537 matches Recipient 667)
# Cycle: 540 & 603 (Donor 540 matches Recipient 603)
# Cycle: 546 & 640 (Donor 546 matches Recipient 640)
# Cycle: 550 & 643 (Donor 550 matches Recipient 643)
# Cycle: 551 & 638 (Donor 551 matches Recipient 638)
# Cycle: 555 & 671 (Donor 555 matches Recipient 671)
# Cycle: 561 & 653 (Donor 561 matches Recipient 653)
# Cycle: 564 & 660 (Donor 564 matches Recipient 660)
# Cycle: 567 & 662 (Donor 567 matches Recipient 662)
# Cycle: 568 & 665 (Donor 568 matches Recipient 665)
# Cycle: 578 & 644 (Donor 578 matches Recipient 644)
# Cycle: 581 & 637 (Donor 581 matches Recipient 637)
# Cycle: 582 & 679 (Donor 582 matches Recipient 679)
# Cycle: 584 & 675 (Donor 584 matches Recipient 675)
# Cycle: 585 & 674 (Donor 585 matches Recipient 674)
# Cycle: 586 & 684 (Donor 586 matches Recipient 684)
# Cycle: 590 & 683 (Donor 590 matches Recipient 683)
# Cycle: 592 & 701 (Donor 592 matches Recipient 701)
# Cycle: 594 & 686 (Donor 594 matches Recipient 686)
# Cycle: 595 & 689 (Donor 595 matches Recipient 689)
# Cycle: 597 & 678 (Donor 597 matches Recipient 678)
# Cycle: 598 & 693 (Donor 598 matches Recipient 693)
# Cycle: 599 & 691 (Donor 599 matches Recipient 691)
# Cycle: 601 & 703 (Donor 601 matches Recipient 703)
# Cycle: 602 & 714 (Donor 602 matches Recipient 714)
# Cycle: 610 & 697 (Donor 610 matches Recipient 697)
# Cycle: 611 & 722 (Donor 611 matches Recipient 722)
# Cycle: 614 & 717 (Donor 614 matches Recipient 717)
# Cycle: 618 & 723 (Donor 618 matches Recipient 723)
# Cycle: 619 & 715 (Donor 619 matches Recipient 715)
# Cycle: 625 & 720 (Donor 625 matches Recipient 720)
#
# Selected 3-Way Cycles:
